# %% [markdown]
# [link text](https://)

# %%
import requests
import urllib.request
from bs4 import BeautifulSoup
import re

# %%
URL = "https://www.zangia.mn/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
job_elements = soup.find_all('div', id=re.compile('^ad-'))

for job_element in job_elements:
    name = job_element.find("div", class_="ad")
    company = job_element.find("div", class_="company").a.b.text
    details = name.find('a')['href']
    job = requests.get(URL+details)
    minisoup = BeautifulSoup(job.content, "html.parser")
    additional = minisoup.findAll('div', attrs={'class' : 'details'})
    info = additional[0].text
    result = []
    current_word = ""
    
    for char in info:
        if char.isupper():
            result.append(current_word)
            current_word = char
        else:
            current_word += char
    result.append(current_word)
    start_index = result.index('Салбар') if 'Салбар' in result else None
    end_index = None
    
    for i in range(len(result)):
        if result[i].startswith('Цалин'):
            end_index = i
            break
            
    if start_index is not None and end_index is not None and start_index < end_index:
        result = result[start_index:end_index]
    
    salary_element = job_element.find("span", class_="fsal").text
    location_element = job_element.find("span", class_="floc").text
    date_element = job_element.find("span", class_="sdate").text
    
    print("Компани: " + company)
    print("Ажлын зар: " + name.a.b.text)
    print("Цалин: " + salary_element)
    
  
            
    print("Байршил: " + location_element)
    print("Он сар: " + date_element + "\n")
# Out:
# Компани: Альфа филтер ХХК
# Ажлын зар: Технологич инженер
# Цалин: 2,500,000 - 3,000,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 13. 14:51
#
# Компани: Зангиа Портал ХХК
# Ажлын зар: Орчуулагч, редактор
# Цалин: 2,100,000 - 2,500,000
# Салбар: Хэвлэл мэдээлэл,
# Медиа: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 14. 9:32
#
# Компани: Бодь Интернэшнл ХХК
# Ажлын зар: ЗАХИРГААНЫ МЭРГЭЖИЛТЭН
# Цалин: 1,800,000 - 2,100,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 9. 14:21
#
# Компани: Юнигаз ХХК
# Ажлын зар: Автогазын борлуулалтын менежер
# Цалин: 1,500,000 - 1,800,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 13. 14:45
#
# Компани: Бишрэлт Групп
# Ажлын зар: ХУДАЛДААНЫ ЗӨВЛӨХ  /БРЭНД ГОО САЙХНЫ ДЭЛГҮҮР/
# Цалин: 1,200,000 - 1,500,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 7. 9:39
#
# Компани: Мобиком корпораци ХХК
# Ажлын зар: ПРОГРАМ ХӨГЖҮҮЛЭГЧ /Монгол контент/
# Цалин: 1,800,000 - 2,100,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 14. 17:18
#
# Компани: Макс Групп
# Ажлын зар: Үйл ажиллагааны ахлах менежер
# Цалин: 1,800,000 - 2,100,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 9. 14:20
#
# Компани: Бодь Интернэшнл ХХК
# Ажлын зар: МЭДЭЭЛЛИЙН АЖИЛТАН /РЕСЕПШН/
# Цалин: 1,200,000 - 1,500,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 9. 14:20
#
# Компани: Бодь Интернэшнл ХХК
# Ажлын зар: НЯГТЛАН БОДОГЧ
# Цалин: 1,800,000 - 2,100,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 9. 14:20
#
# Компани: Стөүнхиж ХХК
# Ажлын зар: Барилгын материалын үйлдвэрлэлийн технологич
# Цалин: 2,500,000 - 3,000,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот, Баянгол дүүрэг
# Он сар: 3 сарын 9. 12:12
#
# Компани: Таван Богд Солюшнс ХХК
# Ажлын зар: Хүний нөөцийн ажилтан
# Цалин: 1,500,000 - 1,800,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:56
#
# Компани: Добу технологи ХХК
# Ажлын зар: Ерөнхий нягтлан бодогч
# Цалин: 2,500,000 - 3,000,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Дунд шатны удирдлага
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:56
#
# Компани: Угсрах Увидас ХХК
# Ажлын зар: Барилгын төсөвчин ажилд авна.
# Цалин: 2,100,000 - 2,500,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:53
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Хуулийн хэлтсийн  ахлах мэргэжилтэн
# Цалин: 1,800,000 - 2,100,000
# Салбар: Хууль, хуулийн үйлчилгээ
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Дотоод хяналтын мэргэжилтэн
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Харилцагчдад туслах ажилтан
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Call center operator
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Зээлийн ажилтан
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Борлуулалтын менежер
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Эргэн төлөлтийн менежер
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Гуанжоу Институте
# Ажлын зар: Солонгос хэлтэй сургалтын менежер
# Цалин: 1,500,000 - 1,800,000
# Салбар: Боловсрол,
# Шинжлэх ухаан: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Утасны оператор
# Цалин: 1,000,000 - 1,200,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:52
#
# Компани: Анлок вишн финанс ХХК
# Ажлын зар: Зээлийн эдийн засагч
# Цалин: 1,200,000 - 1,500,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Чингэлтэй дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Харилцагчийн бүртгэлийн ажилтан
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Бараа материалын нярав
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Баяндэмбэрэл ХХК
# Ажлын зар: МЕНЕЖЕР
# Цалин: 1,500,000 - 1,800,000
# Салбар: Үйлчилгээ
# Түвшин: Дунд шатны удирдлага
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 11:24
#
# Компани: Баянгол мед ХХК
# Ажлын зар: Эмнэлгийн тоног төхөөрөмжийн борлуулалтын менежер
# Цалин: 1,800,000 - 2,100,000
# Салбар: Эмнэлэг,
# Эм хангамж: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 1. 11:31
#
# Компани: Шангри-Ла Улаанбаатар ХХК
# Ажлын зар: Executive Secretary /Maternity Cover/
# Цалин: 2,100,000 - 2,500,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 10. 17:07
#
# Компани: КоллПро ХХК
# Ажлын зар: BACKEND DEVELOPER
# Цалин: 2,100,000 - 2,500,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 11:19
#
# Компани: Шангри-Ла Улаанбаатар ХХК
# Ажлын зар: Борлуулалтын ахлах ажилтан
# Цалин: 1,800,000 - 2,100,000
# Салбар: Үйлчилгээ
# Байршил: Улаанбаатар хот
# Он сар: 2 сарын 28. 9:55
#
# Компани: РЕМАКС Платин
# Ажлын зар: Видео, зурган контент хөгжүүлэгч
# Цалин: 2,100,000 - 2,500,000
# Салбар: Дизайн,
# Энтертайнмент, : Соёл урлаг
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 14. 16:53
#
# Компани: Шангри-Ла Улаанбаатар ХХК
# Ажлын зар: Leasing Coordinator
# Цалин: 1,800,000 - 2,100,000
# Салбар: Үйлчилгээ
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 6. 9:52
#
# Компани: Тэсо Групп
# Ажлын зар: МЭДЭЭЛЛИЙН АЮУЛГҮЙ БАЙДЛЫН МЭРГЭЖИЛТЭН
# Цалин: 2,100,000 - 2,500,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Сонгинохайрхан дүүрэг
# Он сар: 3 сарын 7. 12:02
#
# Компани: ОРГИЛ ТУРБИН ИНЖЕНЕРИНГ ХХК
# Ажлын зар: ДИЗАЙНЕР АЖИЛД АВНА
# Цалин: 1,200,000 - 1,500,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 10. 9:37
#
# Компани: Рапид Девелопмент Групп ХХК
# Ажлын зар: АРХИТЕКТОР
# Цалин: 2,100,000 - 2,500,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 2 сарын 27. 17:28
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Сургалт хариуцсан менежер
# Цалин: 1,500,000 - 1,800,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: PR мэргэжилтэн
# Цалин: 1,500,000 - 1,800,000
# Салбар: Маркетинг,
# P: R,
# Менежмент: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Дата бүртгэлийн ажилтан
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Сайн Интернэшнл ХХК
# Ажлын зар: Авлагын нягтлан
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Гуанжоу Институте
# Ажлын зар: Англи хэлтэй сургалтын менежер
# Цалин: 1,500,000 - 1,800,000
# Салбар: Боловсрол,
# Шинжлэх ухаан: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:51
#
# Компани: Хаан булаг Интернэйшнл ХХК
# Ажлын зар: Захирлын туслах / Англи  хэлтэй/
# Цалин: 1,800,000 - 2,100,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:48
#
# Компани: Bimex holding
# Ажлын зар: Харилцагчийн үйлчилгээний ажилтан
# Цалин: 1,200,000 - 1,500,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:47
#
# Компани: Эм Эс Эй Майнинг Скиллс ХХК
# Ажлын зар: Full stack developer
# Цалин: 3,000,000 - 4,000,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Чингэлтэй дүүрэг
# Он сар: 3 сарын 15. 16:46
#
# Компани: Хэв Хашмал ХХК
# Ажлын зар: үйлчлэгч
# Цалин: 800,000 - 1,000,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:46
#
# Компани: ГРИЙН ИНДАСТРИ ХХК
# Ажлын зар: Худалдааны төлөөлөгч /Жижиглэн/
# Цалин: 1,800,000 - 2,100,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Сонгинохайрхан дүүрэг
# Он сар: 3 сарын 15. 16:45
#
# Компани: Хэв Хашмал ХХК
# Ажлын зар: туслах ажилчин
# Цалин: 1,200,000 - 1,500,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:45
#
# Компани: Таван Богд Интернэйшнл ХХК
# Ажлын зар: ХУДАЛДААНЫ ТӨЛӨӨЛӨГЧ /Хувьдаа машинтай/ Хорека
# Цалин: 1,500,000 - 1,800,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:43
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Үйл ажиллагаа, санхүүгийн эрсдэлийн менежер
# Цалин: 1,800,000 - 2,100,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:43
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Эрсдэлийн менежер /Стратеги, санхүүгийн эрсдэл/
# Цалин: 1,800,000 - 2,100,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:42
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Төслийн менежер /МТС/
# Цалин: 2,100,000 - 2,500,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Дэлгэр Ингүүмэл
# Ажлын зар: Худалдааны Зөвлөх
# Цалин: 1,000,000 - 1,200,000
# Салбар: Худалдаа,
# Борлуулалт: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 14. 12:56
#
# Компани: Баянгол мед ХХК
# Ажлын зар: Эм зүйч менежер ажилд авна.
# Цалин: 1,800,000 - 2,100,000
# Салбар: Эмнэлэг,
# Эм хангамж: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 2 сарын 27. 11:33
#
# Компани: Гүнд инвестмент холдинг групп
# Ажлын зар: Оффис менежер /National life insurance/
# Цалин: 1,000,000 - 1,200,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Баянгол дүүрэг
# Он сар: 3 сарын 14. 14:55
#
# Компани: Заг ХХК
# Ажлын зар: АВТОСАМОСВАЛЫН ЖОЛООЧ
# Цалин: 1,800,000 - 2,100,000
# Салбар: Уул уурхай
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Ээлжийн
# Байршил: Өмнөговь аймаг
# Он сар: 3 сарын 10. 11:06
#
# Компани: Заг ХХК
# Ажлын зар: БУЛЬДОЗЕР ОПЕРАТОР
# Цалин: 2,500,000 - 3,000,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Өмнөговь аймаг
# Он сар: 3 сарын 14. 9:11
#
# Компани: Вэлл Бий ХХК
# Ажлын зар: Борлуулалтын нягтлан бодогч
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 13. 11:50
#
# Компани: Гурван Шүтээн ХХК
# Ажлын зар: Маркетингийн менежер ажилд авна
# Цалин: 2,100,000 - 2,500,000
# Салбар: Маркетинг,
# P: R,
# Менежмент: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 13. 9:16
#
# Компани: КоллПро ХХК
# Ажлын зар: FRONTEND DEVELOPER
# Цалин: 2,100,000 - 2,500,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 10:55
#
# Компани: Мон-Энержи Консалт ХХК
# Ажлын зар: Document controller
# Цалин: 1,200,000 - 1,500,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 14. 11:35
#
# Компани: Мон-Энержи Консалт ХХК
# Ажлын зар: Дулааны зургийн инженер
# Цалин: 1,500,000 - 1,800,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 2 сарын 28. 14:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Кассч
# Цалин: 1,000,000 - 1,200,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:41
#
# Компани: Анлок вишн финанс ХХК
# Ажлын зар: Харилцааны мэргэжилтэн
# Цалин: 1,200,000 - 1,500,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Чингэлтэй дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Худалдааны Зөвлөх /эрэгтэй/
# Цалин: 1,000,000 - 1,200,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Суурилуулалтын  техникч
# Цалин: 1,200,000 - 1,500,000
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Хүний нөөцийн менежер
# Цалин: 1,200,000 - 1,500,000
# Салбар: Захиргаа,
# Хүний нөөц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Тооцооны нягтлан бодогч /шинэ төгсөгч байж болно/
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:41
#
# Компани: Брэнд Нью Хотелс ХХК
# Ажлын зар: Тооцоон нягтлан бодогч
# Цалин: 1,500,000 - 1,800,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Худалдааны Зөвлөх  /бүтэн цагийн ажлын байр/
# Цалин: 1,000,000 - 1,200,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:41
#
# Компани: Номин Холдинг ХХК
# Ажлын зар: Программ хангамж, хөгжүүлэлтийн албаны дарга
# Цалин: 5,000,000 -ааc дээш
# Салбар: Мэдээлэл технологи,
# Харилцаа холбоо: Түвшин
# Дунд шатны удирдлага: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:41
#
# Компани: Мирэ Эссет Секьюритис Монгол ҮЦК ХХК
# Ажлын зар: Шинжээч
# Цалин: 1,800,000 - 2,100,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот
# Он сар: 3 сарын 15. 16:41
#
# Компани: РЕМАКС Платин
# Ажлын зар: Үл хөдлөх хөрөнгийн зууч /REAL ESTATE AGENT/
# Цалин: 2,500,000 - 3,000,000
# Салбар: Төрийн болон төрийн бус байгууллага,
# О: У
# Б: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:38
#
# Компани: Бодь Пропертийз
# Ажлын зар: ИНЖЕНЕР /ХАС, ЦБУ/ РОСТЕРООР
# Цалин: 1,800,000 - 2,100,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Өмнөговь аймаг
# Он сар: 3 сарын 15. 16:38
#
# Компани: РЕМАКС Платин
# Ажлын зар: Үл хөдлөх хөрөнгийн зууч /REAL ESTATE AGENT/
# Цалин: 2,500,000 - 3,000,000
# Салбар: Маркетинг,
# P: R,
# Менежмент: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:37
#
# Компани: Оптимал Ревард
# Ажлын зар: Зээлийн эдийн засагч
# Цалин: 1,000,000 - 1,200,000
# Салбар: Банк, санхүү, нягтлан бодох бүртгэл
# Түвшин: Мэргэжилтэн
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Сүхбаатар дүүрэг
# Он сар: 3 сарын 15. 16:36
#
# Компани: Монос Хүнс ХК
# Ажлын зар: МЕРЧИНДАЙЗЕР
# Цалин: 600,000 - 800,000
# Салбар: Худалдаа,
# Борлуулалт: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Хан-Уул дүүрэг
# Он сар: 3 сарын 15. 16:36
#
# Компани: РЕМАКС Платин
# Ажлын зар: Үл хөдлөх хөрөнгийн зууч /REAL ESTATE AGENT/
# Цалин: 2,500,000 - 3,000,000
# Салбар: Аялал жуулчлал, зочид буудал
# Түвшин: Мэргэжил хамаарахгүй
# Төрөл: Бүтэн цагийн
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:36
#
# Компани: Жи Ти Аукон ХХК
# Ажлын зар: Оосорлогч дохиочин /Оюу Толгойн төсөл/
# Цалин: 1,500,000 - 1,800,000
# Салбар: Уул уурхай
# Төрөл: Ээлжийн
# Байршил: Өмнөговь аймаг
# Он сар: 3 сарын 15. 16:35
#
# Компани: РЕМАКС Платин
# Ажлын зар: Үл хөдлөх хөрөнгийн зууч /REAL ESTATE AGENT/
# Цалин: 2,500,000 - 3,000,000
# Салбар: Маркетинг,
# P: R,
# Менежмент: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:35
#
# Компани: Монос Хүнс ХК
# Ажлын зар: ТОНОГ ТӨХӨӨРӨМЖИЙН ОПЕРАТОР
# Цалин: 1,200,000 - 1,500,000
# Салбар: Үйлдвэрлэл,
# Дэд бүтэц: Түвшин
# Мэргэжилтэн: Төрөл
# Байршил: Улаанбаатар хот, Баянгол дүүрэг
# Он сар: 3 сарын 15. 16:35
#
# Компани: РЕМАКС Платин
# Ажлын зар: Үл хөдлөх хөрөнгийн зууч /REAL ESTATE AGENT/
# Цалин: 2,500,000 - 3,000,000
# Салбар: Барилга,
# Үл хөдлөх хөрөнгө: Түвшин
# Мэргэжил хамаарахгүй: Төрөл
# Байршил: Улаанбаатар хот, Баянзүрх дүүрэг
# Он сар: 3 сарын 15. 16:35
